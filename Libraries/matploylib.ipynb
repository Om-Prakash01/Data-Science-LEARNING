# %% [markdown]
# # Matplotlib / Data Visualization :-

# %% [markdown]
# # Types of Data :-
#     • Numerical Data
#     • Categorical Data

# %%
# import the library

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2D line plot :-
